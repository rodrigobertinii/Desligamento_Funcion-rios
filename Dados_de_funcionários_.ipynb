# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigobertinii/Desligamento_Funcion-rios/blob/main/Dados_de_funcion%C3%A1rios_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BANCO DE DADOS SOBRE FUNCIONÁRIOS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# •  **Employee_ID**: Código único atribuído a cada funcionário.
#
# •  **Age**: Idade do funcionário.
#
# •  **Gender**: Gênero do funcionário.
#
# •  **Marital_Status**: Situação conjugal do funcionário.
#
# •  **Department**: Área ou departamento onde o funcionário exerce suas atividades.
#
# •  **Job_Role**: Função ou cargo que o funcionário ocupa dentro do departamento.
#
# •  **Job_Level**: Posição ou nível hierárquico do funcionário na organização.
#
# •  **Monthly_Income**: Remuneração mensal do funcionário. (Dólar)
#
# •  **Hourly_Rate**: Valor pago por hora para funcionários que recebem por hora.(Dólar)
#
# •  **Years_at_Company**: Tempo de serviço do funcionário na empresa.
#
# •  **Years_in_Current_Role**: Tempo que o funcionário permanece no cargo atual.
#
# •  **Years_Since_Last_Promotion**: Período desde a última promoção do funcionário.
#
# •  **Work_Life_Balance**: Avaliação do equilíbrio entre o trabalho e a vida pessoal do funcionário.
#
# •  **Job_Satisfaction**: Grau de satisfação do funcionário com o trabalho, em uma escala de 1 a 5.
#
# •  **Performance_Rating**: Avaliação do desempenho do funcionário, em uma escala de 1 a 5.
#
# •  **Training_Hours_Last_Year**: Total de horas de treinamento realizadas pelo funcionário no ano anterior.
#
# •  **Overtime**: Indicação se o funcionário realiza horas extras.
#
# •  **Project_Count**: Número de projetos que o funcionário gerenciou.
#
# •  **Average_Hours_Worked_Per_Week**: Média de horas trabalhadas pelo funcionário por semana.
#
# •  **Absenteeism**: Quantidade de dias em que o funcionário esteve ausente no último ano.
#
# •  **Work_Environment_Satisfaction**: Avaliação da satisfação do funcionário com o ambiente de trabalho.
#
# •  **Relationship_with_Manager**: Avaliação do relacionamento do funcionário com o gerente.
#
# •  **Job_Involvement**: Grau de envolvimento do funcionário com suas funções de trabalho.
#
# •  **Distance_From_Home**: Distância entre a residência do funcionário e o local de trabalho. (Km)
#
# •  **Number_of_Companies_Worked**: Quantidade de empresas nas quais o funcionário já trabalhou.
#
# •  **Attrition**: Coluna de destino (Sim/Não) que indica se o funcionário deixou a empresa.

# %% [markdown]
# Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Carregamento do Banco de Dados

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projetos GitHub/Dados de funcionários /employee_attrition_dataset_10000.csv')

# %% [markdown]
# Mostrar 4 linhas do Banco de Dados

# %%
df.sample(4)
# Out:
#       Employee_ID  Age  Gender Marital_Status Department   Job_Role  \
# 685           686   58    Male        Married         HR    Analyst
# 6976         6977   57  Female         Single    Finance  Executive
# 701           702   24  Female        Married         HR    Manager
# 4300         4301   44    Male        Married         IT    Analyst
#
#       Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 685           1           10866           98                17  ...        No
# 6976          1           14966           98                16  ...        No
# 701           5           10369           26                27  ...        No
# 4300          5           11218           25                27  ...       Yes
#
#       Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# 685               6                             54           12
# 6976              8                             57           10
# ...

# %% [markdown]
# Analisar os dados estatísticos

# %%
df.describe()
# Out:
#        Employee_ID           Age     Job_Level  Monthly_Income   Hourly_Rate  \
# count  10000.00000  10000.000000  10000.000000    10000.000000  10000.000000
# mean    5000.50000     39.561800      2.990800    11436.716700     57.032300
# std     2886.89568     11.454986      1.410643     4926.528302     24.703261
# min        1.00000     20.000000      1.000000     3000.000000     15.000000
# 25%     2500.75000     30.000000      2.000000     7182.500000     36.000000
# 50%     5000.50000     40.000000      3.000000    11401.500000     57.000000
# 75%     7500.25000     49.000000      4.000000    15679.500000     78.000000
# max    10000.00000     59.000000      5.000000    19999.000000     99.000000
#
#        Years_at_Company  Years_in_Current_Role  Years_Since_Last_Promotion  \
# count      10000.000000           10000.000000                10000.000000
# mean          14.936200               7.451300                    4.471900
# ...

# %% [markdown]
# Descobrir a quantidade de linhas e colunas do banco

# %%
linhas, colunas = df.shape
print(f'O banco de dados possui {linhas} linhas e {colunas} colunas')
# Out:
# O banco de dados possui 10000 linhas e 26 colunas

# %% [markdown]
# Nome das colunas

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Marital_Status', 'Department',
#        'Job_Role', 'Job_Level', 'Monthly_Income', 'Hourly_Rate',
#        'Years_at_Company', 'Years_in_Current_Role',
#        'Years_Since_Last_Promotion', 'Work_Life_Balance', 'Job_Satisfaction',
#        'Performance_Rating', 'Training_Hours_Last_Year', 'Overtime',
#        'Project_Count', 'Average_Hours_Worked_Per_Week', 'Absenteeism',
#        'Work_Environment_Satisfaction', 'Relationship_with_Manager',
#        'Job_Involvement', 'Distance_From_Home', 'Number_of_Companies_Worked',
#        'Attrition'],
#       dtype='object')

# %% [markdown]
# Informações do tipo de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Employee_ID                    10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Gender                         10000 non-null  object
#  3   Marital_Status                 10000 non-null  object
#  4   Department                     10000 non-null  object
#  5   Job_Role                       10000 non-null  object
#  6   Job_Level                      10000 non-null  int64
#  7   Monthly_Income                 10000 non-null  int64
#  8   Hourly_Rate                    10000 non-null  int64
#  9   Years_at_Company               10000 non-null  int64
#  10  Years_in_Current_Role          10000 non-null  int64
#  11  Years_Since_Last_Promotion     10000 non-null  int64
# ...

# %% [markdown]
# Analisar se possui dados duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Não foram encontrados dados duplicados

# %% [markdown]
# Analisar se possui dados vazios

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Não foram encontrados dados vazios

# %% [markdown]
# Contagem dos valores distintos das colunas categoricas

# %%
df.select_dtypes(include=['object', 'category']).columns

for column in list(df.select_dtypes(include=['object', 'category']).columns):
    print('-'*35)
    print(df[f'{column}'].value_counts())
    print('-'*35)
# Out:
# -----------------------------------
# Gender
# Female    5042
# Male      4958
# Name: count, dtype: int64
# -----------------------------------
# -----------------------------------
# Marital_Status
# Married     3375
# Divorced    3330
# Single      3295
# Name: count, dtype: int64
# -----------------------------------
# -----------------------------------
# Department
# Marketing    2133
# Sales        2008
# Finance      1990
# HR           1953
# IT           1916
# Name: count, dtype: int64
# -----------------------------------
# -----------------------------------
# Job_Role
# Analyst      2572
# Assistant    2538
# Executive    2476
# Manager      2414
# Name: count, dtype: int64
# -----------------------------------
# -----------------------------------
# Overtime
# No     5103
# Yes    4897
# Name: count, dtype: int64
# -----------------------------------
# -----------------------------------
# Attrition
# No     8003
# Yes    1997
# Name: count, dtype: int64
# ...

# %% [markdown]
# Saber se existe relação entre as colunas

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(20, 13))
sns.heatmap(correlation_matrix, square=True,
            annot=True, fmt='.1f', linewidths=0.1, cmap='coolwarm');

# %% [markdown]
# No caso, não existe nenhuma relação entre as colunas

# %% [markdown]
# Analisar os desligamentos por departamentos

# %%
fig = px.histogram(df, x='Department', color='Attrition')
fig.update_layout(
    title='Desligamento por Departamento',
    xaxis_title='Departamentos',
    yaxis_title='Frequência')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Histograma com a distribuição das idades do funcionários

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=38, color='green')
plt.title('Distribuição de idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# Construção de um gráfico de pizza sobre a distribuição de Gênero

# %%
plt.figure(figsize=(6, 6))
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['#FF7F7F', '#7FBFFF'])
plt.title('Distribuição de Gênero')
plt.ylabel('')
plt.show()

# %% [markdown]
# Ver comparativo de quantos funcionários foram desligados e quantos não

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Attrition', data=df, palette={'Yes': '#FF6347', 'No': '#1E90FF'})
plt.title('Contagem de Desligamentos de Funcionários')
plt.xlabel('Desligamentos')
plt.ylabel('Contagem')
plt.show()
# Out:
# <ipython-input-18-5f777a612ee4>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Exportação do arquivo após tratamento de dados

# %%
df.to_csv('df.csv', index=False)

# %% [markdown]
# Nesse banco de dados, não ocorreu nenhuma alteração, pois os dados não precisaram de alteração.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
